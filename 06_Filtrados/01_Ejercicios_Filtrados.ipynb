# %% [markdown]
# # Ejercicios filtrados

# %%
import pandas as pd

# %%
import os
os.chdir(r"C:\americo\ia_dema\06_Filtrados")

# %% [markdown]
# # Cargar los DataFrames catas_vino1 y catas_vino2

# %%
catas_vino1 = pd.read_csv("catas_vino1.csv", sep=";", encoding="latin-1")

# %%
catas_vino1
# Out:
#       citric acid  residual sugar  chlorides  free sulfur dioxide  \
# 0            0.40             6.1      0.034                 36.0
# 1            0.51             2.0      0.046                 11.0
# 2            0.38            10.5      0.031                 53.0
# 3            0.30             5.0      0.040                 40.0
# 4            0.26             1.4      0.041                 40.0
# ...           ...             ...        ...                  ...
# 3276         0.52             6.5      0.047                 28.0
# 3277         0.32             9.0      0.039                 54.0
# 3278         0.52             3.2      0.043                 28.0
# 3279         0.29            13.7      0.035                 53.0
# 3280         0.35             1.7      0.030                 38.0
#
#       total sulfur dioxide  density    pH  sulphates  alcohol  quality  taste
# 0                    118.0  0.99144  3.21       0.43     12.1        7   3167
# ...

# %%
catas_vino2 = pd.read_csv("catas_vino2.csv", sep=";", encoding="latin-1")

# %%
catas_vino2
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.5              0.29         0.36            15.7      0.050
# 1               6.9              0.42         0.20            15.4      0.043
# 2               7.6              0.28         0.39             1.9      0.052
# 3               6.9              0.22         0.37            15.0      0.053
# 4               7.1              0.23         0.39             1.6      0.032
# ...             ...               ...          ...             ...        ...
# 3276            6.8              0.25         0.38             8.1      0.046
# 3277            6.1              0.22         0.46             1.8      0.160
# 3278            6.8              0.26         0.46             8.3      0.037
# 3279            6.6              0.22         0.28             4.9      0.042
# 3280            6.0              0.27         0.40             1.7      0.021
#
# ...

# %% [markdown]
# ## Colocar la columna taste como índice de ambas tablas

# %%
df_catas_vino1 = catas_vino1.set_index('taste').sort_index()

# %%
df_catas_vino1.head(10)
# Out:
#        citric acid  residual sugar  chlorides  free sulfur dioxide  \
# taste
# 0             0.36           20.70      0.045                 45.0
# 1             0.34            1.60      0.049                 14.0
# 2             0.40            6.90      0.050                 30.0
# 3             0.32            8.50      0.058                 47.0
# 4             0.32            8.50      0.058                 47.0
# 5             0.40            6.90      0.050                 30.0
# 6             0.16            7.00      0.045                 30.0
# 7             0.36           20.70      0.045                 45.0
# 9             0.43            1.50      0.044                 28.0
# 10            0.41            1.45      0.033                 11.0
#
#        total sulfur dioxide  density    pH  sulphates  alcohol  quality
# taste
# 0                     170.0   1.0010  3.00       0.45      8.8        6
# ...

# %%
df_catas_vino2 = catas_vino2.set_index('taste').sort_index()

# %%
df_catas_vino2.head(10)
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# taste
# 1                6.3              0.30         0.34            1.60
# 2                8.1              0.28         0.40            6.90
# 5                8.1              0.28         0.40            6.90
# 6                6.2              0.32         0.16            7.00
# 9                8.1              0.22         0.43            1.50
# 11               8.6              0.23         0.40            4.20
# 12               7.9              0.18         0.37            1.20
# 13               6.6              0.16         0.40            1.50
# 14               8.3              0.42         0.62           19.25
# 16               6.3              0.48         0.04            1.10
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  alcohol  quality
# taste
# 1          0.049                 14.0                 132.0      9.5        6
# ...

# %%
print(df_catas_vino1.columns)
print(df_catas_vino2.columns)
# Out:
# Index(['citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'alcohol',
#        'quality'],
#       dtype='object')

# %% [markdown]
# ## Determinar qué columnas están presentes en catas1 y no en catas2 y viceversa.

# %%
#df_catas_vino1.symmetric_difference(df_catas_vino2)
solo_en_catas_vino1 = catas_vino1.columns.difference(catas_vino2.columns)
solo_en_catas_vino2 = catas_vino2.columns.difference(catas_vino1.columns)

# %%
print('columnas solo en catas_vino1: ',solo_en_catas_vino1)
print('columnas solo en catas_vino2: ', solo_en_catas_vino2)
# Out:
# columnas solo en catas_vino1:  Index(['density', 'pH', 'sulphates'], dtype='object')
# columnas solo en catas_vino2:  Index(['fixed acidity', 'volatile acidity'], dtype='object')

# %%
catas_vino1.columns.symmetric_difference(catas_vino2.columns)
# Out:
# Index(['density', 'fixed acidity', 'pH', 'sulphates', 'volatile acidity'], dtype='object')

# %% [markdown]
# ## Determinar qué columnas están presentes en ambas tablas.

# %%
catas_vino1.columns.intersection(catas_vino2.columns)
# Out:
# Index(['citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'alcohol', 'quality', 'taste'],
#       dtype='object')

# %%
catas_vino1[catas_vino1.columns.intersection(catas_vino2.columns)]
# Out:
#       citric acid  residual sugar  chlorides  free sulfur dioxide  \
# 0            0.40             6.1      0.034                 36.0
# 1            0.51             2.0      0.046                 11.0
# 2            0.38            10.5      0.031                 53.0
# 3            0.30             5.0      0.040                 40.0
# 4            0.26             1.4      0.041                 40.0
# ...           ...             ...        ...                  ...
# 3276         0.52             6.5      0.047                 28.0
# 3277         0.32             9.0      0.039                 54.0
# 3278         0.52             3.2      0.043                 28.0
# 3279         0.29            13.7      0.035                 53.0
# 3280         0.35             1.7      0.030                 38.0
#
#       total sulfur dioxide  alcohol  quality  taste
# 0                    118.0     12.1        7   3167
# 1                    207.0     11.4        5    324
# ...

# %%
catas_vino2[catas_vino2.columns.intersection(catas_vino1.columns)]
# Out:
#       citric acid  residual sugar  chlorides  free sulfur dioxide  \
# 0            0.36            15.7      0.050                 29.0
# 1            0.20            15.4      0.043                 57.0
# 2            0.39             1.9      0.052                 23.0
# 3            0.37            15.0      0.053                 59.0
# 4            0.39             1.6      0.032                 12.0
# ...           ...             ...        ...                  ...
# 3276         0.38             8.1      0.046                 24.0
# 3277         0.46             1.8      0.160                 34.0
# 3278         0.46             8.3      0.037                 49.0
# 3279         0.28             4.9      0.042                 51.0
# 3280         0.40             1.7      0.021                 18.0
#
#       total sulfur dioxide    alcohol  quality  taste
# 0                    124.0  10.400000        5   3320
# 1                    201.0   9.400000        5   4271
# ...

# %% [markdown]
# ## Determinar qué filas están presentes en catas1 y no en catas2 y viceversa.

# %%
df1_unicos = df_catas_vino1.index.difference(df_catas_vino2.index)

# %%
df2_unicos = df_catas_vino2.index.difference(df_catas_vino1.index)

# %%
print("En catas_vino1 pero no en catas_vino2:\n", df1_unicos)
# Out:
# En catas_vino1 pero no en catas_vino2:
#  Index([   0,    3,    4,    7,   10,   15,   24,   27,   38,   40,
#        ...
#        4851, 4855, 4860, 4861, 4864, 4868, 4871, 4878, 4885, 4895],
#       dtype='int64', name='taste', length=1065)

# %%
print("En catas_vino2 pero no en catas_vino1:\n", df2_unicos)
# Out:
# En catas_vino2 pero no en catas_vino1:
#  Index([  12,   14,   17,   19,   23,   31,   32,   43,   44,   45,
#        ...
#        4856, 4857, 4866, 4873, 4875, 4879, 4893, 4894, 4896, 4897],
#       dtype='int64', name='taste', length=1065)

# %%
df_catas_vino1.loc[df_catas_vino1.index.difference(df_catas_vino2.index)]
# Out:
#        citric acid  residual sugar  chlorides  free sulfur dioxide  \
# taste
# 0             0.36           20.70      0.045                 45.0
# 3             0.32            8.50      0.058                 47.0
# 4             0.32            8.50      0.058                 47.0
# 7             0.36           20.70      0.045                 45.0
# 10            0.41            1.45      0.033                 11.0
# ...            ...             ...        ...                  ...
# 4868          0.31            4.50      0.046                 42.0
# 4871          0.40            1.90      0.015                 20.0
# 4878          0.02            0.90      0.035                  6.0
# 4885          0.40            8.10      0.046                 68.0
# 4895          0.19            1.20      0.041                 30.0
#
#        total sulfur dioxide  density    pH  sulphates  alcohol  quality
# taste
# 0                     170.0  1.00100  3.00       0.45     8.80        6
# ...

# %%
df_catas_vino2.loc[df_catas_vino2.index.difference(df_catas_vino1.index)]
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# taste
# 12               7.9              0.18         0.37            1.20
# 14               8.3              0.42         0.62           19.25
# 17               6.2              0.66         0.48            1.20
# 19               6.5              0.31         0.14            7.50
# 23               7.6              0.67         0.14            1.50
# ...              ...               ...          ...             ...
# 4879             6.6              0.34         0.40            8.10
# 4893             6.2              0.21         0.29            1.60
# 4894             6.6              0.32         0.36            8.00
# 4896             5.5              0.29         0.30            1.10
# 4897             6.0              0.21         0.38            0.80
#
#        chlorides  free sulfur dioxide  total sulfur dioxide    alcohol  \
# taste
# ...

# %% [markdown]
# ## Determinar qué filas están presentes en ambas tablas.

# %%
df_catas_vino1.index
# Out:
# Index([3167,  324, 4731, 2305, 1777, 3185, 2929, 1498, 1502, 1006,
#        ...
#        1685,  130, 2919, 3171, 3444, 4426,  466, 3092, 3772,  860],
#       dtype='int64', name='taste', length=3281)

# %%
df_catas_vino2.index
# Out:
# Index([3320, 4271, 1370,  782,  491, 1380, 1219, 4415, 2898,  602,
#        ...
#        2862, 3962,  604, 4829,   28,  826, 3735, 2942, 2064, 4818],
#       dtype='int64', name='taste', length=3281)

# %%
# 1. Obtén el índice común (los valores de ‘taste’ que están en ambos)
common_idx = df_catas_vino1.index.intersection(df_catas_vino2.index)

# %%
common_idx
# Out:
# Index([3167,  324, 4731, 2305, 1777, 3185, 2929, 4112, 3418, 1467,
#        ...
#        1685,  130, 2919, 3171, 3444, 4426,  466, 3092, 3772,  860],
#       dtype='int64', name='taste', length=2216)

# %%
# 2. Extrae esas filas de cada DataFrame
common_df1 = df_catas_vino1.loc[common_idx]

common_df1
# Out:
#        citric acid  residual sugar  chlorides  free sulfur dioxide  \
# taste
# 3167          0.40             6.1      0.034                 36.0
# 324           0.51             2.0      0.046                 11.0
# 4731          0.38            10.5      0.031                 53.0
# 2305          0.30             5.0      0.040                 40.0
# 1777          0.26             1.4      0.041                 40.0
# ...            ...             ...        ...                  ...
# 4426          0.52             6.5      0.047                 28.0
# 466           0.32             9.0      0.039                 54.0
# 3092          0.52             3.2      0.043                 28.0
# 3772          0.29            13.7      0.035                 53.0
# 860           0.35             1.7      0.030                 38.0
#
#        total sulfur dioxide  density    pH  sulphates  alcohol  quality
# taste
# 3167                  118.0  0.99144  3.21       0.43     12.1        7
# ...

# %%
common_df2 = df_catas_vino2.loc[common_idx]

common_df2
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# taste
# 3167             5.6              0.28         0.40             6.1
# 324              8.3              0.41         0.51             2.0
# 4731             5.3              0.31         0.38            10.5
# 2305             7.0              0.36         0.30             5.0
# 1777             6.5              0.18         0.26             1.4
# ...              ...               ...          ...             ...
# 4426             6.2              0.21         0.52             6.5
# 466              7.0              0.14         0.32             9.0
# 3092             7.6              0.27         0.52             3.2
# 3772             6.3              0.24         0.29            13.7
# 860              8.1              0.27         0.35             1.7
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  alcohol  quality
# taste
# ...

# %% [markdown]
# ## Filtrar las filas de catas1 para las que tenemos datos en catas2

# %% [markdown]
# ## Comprobar si la calidad de las catas que están presentes en catas2 pero
#
# ## no en catas1 es mayor o menor que la calidad de las de catas1
