# %% [markdown]
# # Ejercicios filtrados

# %%
import pandas as pd

# %%
import os
os.chdir("/content/sample_data")

# %%
catas1 = pd.read_csv("catas_vino1.csv", sep = ";")
catas2 = pd.read_csv("catas_vino2.csv", sep = ";")

# %%
catas1
# Out:
#       citric acid  residual sugar  chlorides  free sulfur dioxide  \
# 0            0.40             6.1      0.034                 36.0
# 1            0.51             2.0      0.046                 11.0
# 2            0.38            10.5      0.031                 53.0
# 3            0.30             5.0      0.040                 40.0
# 4            0.26             1.4      0.041                 40.0
# ...           ...             ...        ...                  ...
# 3276         0.52             6.5      0.047                 28.0
# 3277         0.32             9.0      0.039                 54.0
# 3278         0.52             3.2      0.043                 28.0
# 3279         0.29            13.7      0.035                 53.0
# 3280         0.35             1.7      0.030                 38.0
#
#       total sulfur dioxide  density    pH  sulphates  alcohol  quality  taste
# 0                    118.0  0.99144  3.21       0.43     12.1        7   3167
# ...

# %%
catas2
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.5              0.29         0.36            15.7      0.050
# 1               6.9              0.42         0.20            15.4      0.043
# 2               7.6              0.28         0.39             1.9      0.052
# 3               6.9              0.22         0.37            15.0      0.053
# 4               7.1              0.23         0.39             1.6      0.032
# ...             ...               ...          ...             ...        ...
# 3276            6.8              0.25         0.38             8.1      0.046
# 3277            6.1              0.22         0.46             1.8      0.160
# 3278            6.8              0.26         0.46             8.3      0.037
# 3279            6.6              0.22         0.28             4.9      0.042
# 3280            6.0              0.27         0.40             1.7      0.021
#
# ...

# %% [markdown]
# ## Colocar la columna taste como índice de ambas tablas

# %%
# catas1[catas1.index.isin(catas2.index)]

catas1 = catas1.set_index("taste").sort_index()
catas2 = catas2.set_index("taste").sort_index()

# %%
catas1.head(15)
# Out:
#        citric acid  residual sugar  chlorides  free sulfur dioxide  \
# taste
# 0             0.36           20.70      0.045                 45.0
# 1             0.34            1.60      0.049                 14.0
# 2             0.40            6.90      0.050                 30.0
# 3             0.32            8.50      0.058                 47.0
# 4             0.32            8.50      0.058                 47.0
# 5             0.40            6.90      0.050                 30.0
# 6             0.16            7.00      0.045                 30.0
# 7             0.36           20.70      0.045                 45.0
# 9             0.43            1.50      0.044                 28.0
# 10            0.41            1.45      0.033                 11.0
# 11            0.40            4.20      0.035                 17.0
# 13            0.40            1.50      0.044                 48.0
# 15            0.38            1.50      0.032                 28.0
# ...

# %%
catas2.head(10)
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# taste
# 1                6.3              0.30         0.34            1.60
# 2                8.1              0.28         0.40            6.90
# 5                8.1              0.28         0.40            6.90
# 6                6.2              0.32         0.16            7.00
# 9                8.1              0.22         0.43            1.50
# 11               8.6              0.23         0.40            4.20
# 12               7.9              0.18         0.37            1.20
# 13               6.6              0.16         0.40            1.50
# 14               8.3              0.42         0.62           19.25
# 16               6.3              0.48         0.04            1.10
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  alcohol  quality
# taste
# 1          0.049                 14.0                 132.0      9.5        6
# ...

# %% [markdown]
# ## Determinar qué columnas están presentes en catas1 y no en catas2 y viceversa.

# %%
catas1.columns.difference(catas2.columns)
# Out:
# Index(['density', 'pH', 'sulphates'], dtype='object')

# %%
catas1[catas1.columns.difference(catas2.columns)]
# Out:
#        density    pH  sulphates
# taste
# 0      1.00100  3.00       0.45
# 1      0.99400  3.30       0.49
# 2      0.99510  3.26       0.44
# 3      0.99560  3.19       0.40
# 4      0.99560  3.19       0.40
# ...        ...   ...        ...
# 4888   0.99330  3.04       0.54
# 4889   0.99540  3.07       0.50
# 4890   0.98938  3.06       0.44
# 4892   0.99298  3.29       0.54
# 4895   0.99254  2.99       0.46
#
# [3281 rows x 3 columns]

# %%
catas2.columns.difference(catas1.columns)
# Out:
# Index(['fixed acidity', 'volatile acidity'], dtype='object')

# %%
catas2[catas2.columns.difference(catas1.columns)]
# Out:
#        fixed acidity  volatile acidity
# taste
# 1                6.3              0.30
# 2                8.1              0.28
# 5                8.1              0.28
# 6                6.2              0.32
# 9                8.1              0.22
# ...              ...               ...
# 4892             6.5              0.23
# 4893             6.2              0.21
# 4894             6.6              0.32
# 4896             5.5              0.29
# 4897             6.0              0.21
#
# [3281 rows x 2 columns]

# %% [markdown]
# ## Determinar qué columnas están presentes en ambas tablas.

# %%
catas1.columns.intersection(catas2.columns)
# Out:
# Index(['citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# ## Determinar qué filas están presentes en catas1 y no en catas2 y viceversa.

# %%
catas1.index.difference(catas2.index)
# Out:
# Index([   0,    3,    4,    7,   10,   15,   24,   27,   38,   40,
#        ...
#        4851, 4855, 4860, 4861, 4864, 4868, 4871, 4878, 4885, 4895],
#       dtype='int64', name='taste', length=1065)

# %%
catas2.index.difference(catas1.index)
# Out:
# Index([  12,   14,   17,   19,   23,   31,   32,   43,   44,   45,
#        ...
#        4856, 4857, 4866, 4873, 4875, 4879, 4893, 4894, 4896, 4897],
#       dtype='int64', name='taste', length=1065)

# %%
catas2.loc[catas2.index.difference(catas1.index)]
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# taste
# 12               7.9              0.18         0.37            1.20
# 14               8.3              0.42         0.62           19.25
# 17               6.2              0.66         0.48            1.20
# 19               6.5              0.31         0.14            7.50
# 23               7.6              0.67         0.14            1.50
# ...              ...               ...          ...             ...
# 4879             6.6              0.34         0.40            8.10
# 4893             6.2              0.21         0.29            1.60
# 4894             6.6              0.32         0.36            8.00
# 4896             5.5              0.29         0.30            1.10
# 4897             6.0              0.21         0.38            0.80
#
#        chlorides  free sulfur dioxide  total sulfur dioxide    alcohol  \
# taste
# ...

# %% [markdown]
# ## Determinar qué filas están presentes en ambas tablas.

# %%
catas1.index.intersection(catas2.index)
# Out:
# Index([   1,    2,    5,    6,    9,   11,   13,   16,   18,   20,
#        ...
#        4876, 4877, 4880, 4883, 4884, 4887, 4888, 4889, 4890, 4892],
#       dtype='int64', name='taste', length=2216)

# %%
catas1.loc[catas1.index.intersection(catas2.index)]
# Out:
#        citric acid  residual sugar  chlorides  free sulfur dioxide  \
# taste
# 1             0.34            1.60      0.049                 14.0
# 2             0.40            6.90      0.050                 30.0
# 5             0.40            6.90      0.050                 30.0
# 6             0.16            7.00      0.045                 30.0
# 9             0.43            1.50      0.044                 28.0
# ...            ...             ...        ...                  ...
# 4887          0.22            1.90      0.023                  5.0
# 4888          0.36            1.20      0.052                 38.0
# 4889          0.27           11.75      0.030                 34.0
# 4890          0.29            2.20      0.036                 25.0
# 4892          0.38            1.30      0.032                 29.0
#
#        total sulfur dioxide  density    pH  sulphates  alcohol  quality
# taste
# 1                     132.0  0.99400  3.30       0.49      9.5        6
# ...

# %% [markdown]
# ### De otra manera

# %%
catas1.index.isin(catas2.index)
# Out:
# array([False,  True,  True, ...,  True,  True, False])

# %%
catas1[catas1.index.isin(catas2.index)]
# Out:
#        citric acid  residual sugar  chlorides  free sulfur dioxide  \
# taste
# 1             0.34            1.60      0.049                 14.0
# 2             0.40            6.90      0.050                 30.0
# 5             0.40            6.90      0.050                 30.0
# 6             0.16            7.00      0.045                 30.0
# 9             0.43            1.50      0.044                 28.0
# ...            ...             ...        ...                  ...
# 4887          0.22            1.90      0.023                  5.0
# 4888          0.36            1.20      0.052                 38.0
# 4889          0.27           11.75      0.030                 34.0
# 4890          0.29            2.20      0.036                 25.0
# 4892          0.38            1.30      0.032                 29.0
#
#        total sulfur dioxide  density    pH  sulphates  alcohol  quality
# taste
# 1                     132.0  0.99400  3.30       0.49      9.5        6
# ...

# %% [markdown]
# ## Comprobar si la calidad de las catas que están presentes en catas2 pero no en catas1 es mayor o menor que la calidad de las de catas1

# %%
catas2[~catas2.index.isin(catas1.index)]
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# taste
# 12               7.9              0.18         0.37            1.20
# 14               8.3              0.42         0.62           19.25
# 17               6.2              0.66         0.48            1.20
# 19               6.5              0.31         0.14            7.50
# 23               7.6              0.67         0.14            1.50
# ...              ...               ...          ...             ...
# 4879             6.6              0.34         0.40            8.10
# 4893             6.2              0.21         0.29            1.60
# 4894             6.6              0.32         0.36            8.00
# 4896             5.5              0.29         0.30            1.10
# 4897             6.0              0.21         0.38            0.80
#
#        chlorides  free sulfur dioxide  total sulfur dioxide    alcohol  \
# taste
# ...

# %%
catas2[~catas2.index.isin(catas1.index)]["quality"].mean()
# Out:
# np.float64(5.906103286384977)

# %%
catas1['quality'].mean()
# Out:
# np.float64(5.868637610484608)
